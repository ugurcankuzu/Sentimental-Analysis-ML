# %% [markdown]
# <a href="https://colab.research.google.com/github/ugurcankuzu/Sentimental-Analysis-ML/blob/main/LogisticRegressionModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import re

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

import nltk
from nltk import word_tokenize

# !pip install pickle5
import pickle5 as pk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
trainData = pd.read_csv("/content/twitter_training.csv",header=None)
trainData
# Out:
#           0            1         2  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2401  Borderlands  Positive
# 4      2401  Borderlands  Positive
# ...     ...          ...       ...
# 74677  9200       Nvidia  Positive
# 74678  9200       Nvidia  Positive
# 74679  9200       Nvidia  Positive
# 74680  9200       Nvidia  Positive
# 74681  9200       Nvidia  Positive
#
#                                                        3
# 0      im getting on borderlands and i will murder yo...
# 1      I am coming to the borders and I will kill you...
# 2      im getting on borderlands and i will kill you ...
# 3      im coming on borderlands and i will murder you...
# 4      im getting on borderlands 2 and i will murder ...
# ...                                                  ...
# 74677  Just realized that the Windows partition of my...
# 74678  Just realized that my Mac window partition is ...
# ...

# %%
trainData.columns = ["id","takenFrom","type","text"]
trainData
# Out:
#          id    takenFrom      type  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2401  Borderlands  Positive
# 4      2401  Borderlands  Positive
# ...     ...          ...       ...
# 74677  9200       Nvidia  Positive
# 74678  9200       Nvidia  Positive
# 74679  9200       Nvidia  Positive
# 74680  9200       Nvidia  Positive
# 74681  9200       Nvidia  Positive
#
#                                                     text
# 0      im getting on borderlands and i will murder yo...
# 1      I am coming to the borders and I will kill you...
# 2      im getting on borderlands and i will kill you ...
# 3      im coming on borderlands and i will murder you...
# 4      im getting on borderlands 2 and i will murder ...
# ...                                                  ...
# 74677  Just realized that the Windows partition of my...
# 74678  Just realized that my Mac window partition is ...
# ...

# %%
trainDup = trainData

# %%
#Text Format Section

trainDup["lower"] = trainDup.text.str.lower() #Text lowercase convert
trainDup["lower"] = [str(data) for data in trainDup.lower] #Text string convert
trainDup["lower"] = trainDup.lower.apply(lambda x: re.sub('[^A-Za-z0-9 ]+', ' ', x)) #Text filtering using RegEx

trainDup
# Out:
#          id    takenFrom      type  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2401  Borderlands  Positive
# 4      2401  Borderlands  Positive
# ...     ...          ...       ...
# 74677  9200       Nvidia  Positive
# 74678  9200       Nvidia  Positive
# 74679  9200       Nvidia  Positive
# 74680  9200       Nvidia  Positive
# 74681  9200       Nvidia  Positive
#
#                                                     text  \
# 0      im getting on borderlands and i will murder yo...
# 1      I am coming to the borders and I will kill you...
# 2      im getting on borderlands and i will kill you ...
# 3      im coming on borderlands and i will murder you...
# 4      im getting on borderlands 2 and i will murder ...
# ...                                                  ...
# 74677  Just realized that the Windows partition of my...
# 74678  Just realized that my Mac window partition is ...
# ...

# %%
#Text Split Section
textToken = [word_tokenize(str(word)) for word in trainDup.lower]

tokenCount = [item for text in textToken for item in text]

print("Token Count is : {}".format(len(set(tokenCount))))
# Out:
# Token Count is : 30436

# %%
#Ineffective words in english for model

stopWords = nltk.corpus.stopwords.words('english')
stopWords[:10] #Example
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]

# %%
#Vectorizing Texts

vectorizer = CountVectorizer(
    tokenizer = word_tokenize,
    stop_words = stopWords,
    ngram_range = (1,1)
)

# %%
#Split Dataset

Xtrain,Xtest = train_test_split(trainDup,test_size=0.2,shuffle=True)

# %%
XtrainVector = vectorizer.fit_transform(Xtrain.lower)
XtestVector = vectorizer.transform(Xtest.lower)

# %%
YtrainVector = Xtrain.type
YtestVector = Xtest.type

# %%
XtestVector.shape
# Out:
# (14937, 29017)

# %%
Xtest
# Out:
#           id        takenFrom        type  \
# 48779   5973        HomeDepot    Negative
# 18900  12439     WorldOfCraft    Positive
# 31514   7411  LeagueOfLegends    Positive
# 24627   4627           Google     Neutral
# 36771   8308        Microsoft    Positive
# ...      ...              ...         ...
# 30685   7272  LeagueOfLegends    Negative
# 25941    852   AssassinsCreed     Neutral
# 6061     243           Amazon     Neutral
# 27167   1074   AssassinsCreed  Irrelevant
# 19467  12533     WorldOfCraft     Neutral
#
#                                                     text  \
# 48779  @GovLauraKelly ordinance mandate masks in publ...
# 18900  Excited to get back into @Warcraft today! Afte...
# 31514  This is pretty fun guy to watch if any of you ...
# 24627  @sandramyers2252 The Scam Shield app is here! ...
# 36771  Here's what I've came back to! Put dispenser h...
# ...                                                  ...
# ...

# %%
latestModel = None
for i in np.arange(0.1,1.0,0.1):
  accuracy = 0
  model = LogisticRegression(C=i,solver="liblinear",max_iter=200)
  model.fit(XtrainVector,YtrainVector)
  prediction = model.predict(XtestVector)
  calc = accuracy_score(YtestVector,prediction)*100

  print("For C value: {}Accuracy Value: {}".format(i,calc))
  if(calc > accuracy):
    accuracy = calc
    latestModel = model
# Out:
# For C value: 0.1Accuracy Value: 72.5045189797148
# For C value: 0.2Accuracy Value: 76.22012452299658
# /usr/local/lib/python3.8/dist-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# For C value: 0.30000000000000004Accuracy Value: 76.75570730401017
# /usr/local/lib/python3.8/dist-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# For C value: 0.4Accuracy Value: 78.1080538260695
# /usr/local/lib/python3.8/dist-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# For C value: 0.5Accuracy Value: 79.16582981857132
# For C value: 0.6Accuracy Value: 81.97763941889268
# For C value: 0.7000000000000001Accuracy Value: 82.46635870656759
# For C value: 0.8Accuracy Value: 82.9082145009038
# ...

# %%
with open("model.pickle","wb") as f:
  pk.dump(latestModel,f)
